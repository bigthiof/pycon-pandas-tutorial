# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
# titles = pd.read_csv('data/titles.csv')
# titles.head()

titles = pd.read_csv(r'C:\Users\sdiou\Downloads\pycon-pandas-tutorial-master\pycon-pandas-tutorial-master\data\titles.csv')
titles.head()
# Out:
#                       title  year
# 0                 Doux amer  1989
# 1  Jiu wu tuo qiang nu jing  1995
# 2             Breaking Hart  2013
# 3                    Alamid  1967
# 4         The Learning Tree  1969

# %%
# cast = pd.read_csv('data/cast.csv')
# cast.head()

# cast = pd.read_csv('data/cast.csv')
cast = pd.read_csv(r'C:\Users\sdiou\Downloads\pycon-pandas-tutorial-master\pycon-pandas-tutorial-master\data\cast.csv', encoding = 'utf-8')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = titles
c.year.value_counts().head()
# Out:
# year
# 2017    9888
# 2016    8198
# 2015    7564
# 2014    7159
# 2013    6896
# Name: count, dtype: int64

# %%
# %%
c = titles
c.year.value_counts().plot()
plt.show()

# %%
# %%
c = titles
c.year.value_counts().sort_index().plot()
plt.show()

# %%
c = cast
c = c [c.character == 'Kermit the Frog']
c.plot(x = 'year', y='n', kind='scatter')
plt.show()

# %%
c = cast
c.head()[['year','n']]
# Out:
#    year     n
# 0  2015  31.0
# 1  1985  22.0
# 2  2017  10.0
# 3  2015   NaN
# 4  2015   NaN

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
c = titles
c.title.value_counts().sort_values(ascending = False).head(10)
# Out:
# title
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# The Outsider            12
# The Three Musketeers    11
# Maya                    11
# Othello                 11
# Temptation              11
# Freedom                 11
# Kismet                  10
# Name: count, dtype: int64

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
c = titles
c = c [ c.year // 10 * 10 == 1930]
c.year.value_counts().head(3)
# Out:
# year
# 1937    1217
# 1938    1161
# 1936    1153
# Name: count, dtype: int64

# %% [markdown]
# ### Plot the number of films that have been released each decade over the history of cinema.

# %%
c = titles [ titles.year <= 2025]
c ['decade'] = c.year // 10 * 10
c.decade.value_counts().sort_index().plot(kind='bar')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sdiou\AppData\Local\Temp\ipykernel_551768\1916619770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c ['decade'] = c.year // 10 * 10

# %% [markdown]
# ### Plot the number of "Hamlet" films made each decade.

# %%
c = titles [ titles.year <= 2025]
c ['decade'] = c.year // 10 * 10
c = c [c.title == 'Hamlet']
c.decade.value_counts().sort_index().plot(kind='bar')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sdiou\AppData\Local\Temp\ipykernel_551768\4144124534.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c ['decade'] = c.year // 10 * 10

# %% [markdown]
# ### Plot the number of "Rustler" characters in each decade of the history of film.

# %%
c = cast
c = c [c.character == 'Rustler']
c ['decade'] = c.year // 10 * 10
c.decade.value_counts().sort_index().plot(kind='bar')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sdiou\AppData\Local\Temp\ipykernel_551768\897798392.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c ['decade'] = c.year // 10 * 10

# %%
cast
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3442897                           Foxtrot  1988            Lilja Þórisdóttir
# 3442898  Niceland (Population. 1.000.002)  2004    Sigríður Jóna Þórisdóttir
# 3442899                         Skammdegi  1985           Dalla Þórðardóttir
# 3442900                      U.S.S.S.S...  2003  Kristín Andrea Þórðardóttir
# 3442901                 Bye Bye Blue Bird  1999                 Rosa á Rógvu
#
# ...

# %% [markdown]
# ### Plot the number of "Hamlet" characters each decade.

# %%
c = cast [ cast.year <= 2025]
c ['decade'] = c.year // 10 * 10
c = c [c.character == 'Hamlet']
c.decade.value_counts().sort_index().plot(kind='bar')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sdiou\AppData\Local\Temp\ipykernel_551768\3313180786.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c ['decade'] = c.year // 10 * 10

# %% [markdown]
# ### What are the 11 most common character names in movie history?

# %%
c = cast
c.character.value_counts().sort_values(ascending = False).head(11)
# Out:
# character
# Himself        19637
# Dancer         12019
# Extra          10848
# Reporter        7818
# Doctor          6963
# Party Guest     6786
# Student         6631
# Policeman       6424
# Bartender       6290
# Herself         6269
# Minor Role      6203
# Name: count, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Herself" in film history?

# %%
c = cast [ cast.character == 'Herself']
c.name.value_counts().sort_values(ascending = False).head(11)
# Out:
# name
# Queen Elizabeth II           11
# Luisa Horga                   9
# María Luisa (V) Martín        9
# Joyce Brothers                8
# Margaret Thatcher             8
# Hillary Clinton               8
# Joan Rivers                   6
# Oprah Winfrey                 6
# María Isabel (III) Martín     6
# Marilyn Monroe                6
# Rekha                         6
# Name: count, dtype: int64

# %%
c = cast
c[c.character == 'Herself'].name.value_counts().head(10)
# Out:
# name
# Queen Elizabeth II        11
# María Luisa (V) Martín     9
# Luisa Horga                9
# Joyce Brothers             8
# Margaret Thatcher          8
# Hillary Clinton            8
# Sumie Sakai                6
# Marta Berrocal             6
# Inés J. Southern           6
# Rekha                      6
# Name: count, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Himself" in film history?

# %%
c = cast
c[c.character == 'Himself'].name.value_counts().head(10)
# Out:
# name
# Adolf Hitler          91
# Richard Nixon         43
# Ronald Reagan         37
# John F. Kennedy       35
# Winston Churchill     24
# George W. Bush        24
# Martin Luther King    23
# Bill Clinton          22
# Benito Mussolini      21
# Ron Jeremy            20
# Name: count, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1945?

# %%
c = cast [cast.year == 1945]
c.name.value_counts().sort_values(ascending = False).head(10)
# Out:
# name
# Emmett Vogan       37
# Sam (II) Harris    31
# Bess Flowers       28
# Harold Miller      28
# Franklyn Farnum    27
# Nolan Leary        26
# Larry Steers       25
# Herman Hack        25
# Kenner G. Kemp     24
# Tom London         24
# Name: count, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1985?

# %%
c = cast [cast.year == 1985]
c.name.value_counts().sort_values(ascending = False).head(10)
# Out:
# name
# Mammootty        22
# Sukumari         20
# Shakti Kapoor    19
# Raj Babbar       15
# Mohanlal         15
# Lou Scheimer     15
# Aruna Irani      13
# Asrani           13
# Om Shivpuri      13
# Rajesh Khanna    13
# Name: count, dtype: int64

# %% [markdown]
# ### Plot how many roles Mammootty has played in each year of his career.

# %%
c = cast [cast.name == 'Mammootty']
c.year.value_counts().sort_index().plot(kind='line')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the 10 most frequent roles that start with the phrase "Patron in"?

# %%
c = cast[cast.character.str.startswith('Patron in', na=False)]
# c.name.value_counts().sort_values(ascending = False).head(10)
c.character.value_counts().sort_values(ascending = False).head(10)
# Out:
# character
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       8
# Patron in Billiard Parlor        5
# Patron in restaurant             3
# Patron in cabaret                3
# Patron in Club                   3
# Patron in Restaurant             3
# Patron in Bar                    3
# Patron in booth                  2
# Name: count, dtype: int64

# %% [markdown]
# ### What are the 10 most frequent roles that start with the word "Science"?

# %% [markdown]
# ### Plot the n-values of the roles that Judi Dench has played over her career.

# %% [markdown]
# ### Plot the n-values of Cary Grant's roles through his career.

# %% [markdown]
# ### Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %% [markdown]
# ### How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?
