# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
# titles = pd.read_csv('data/titles.csv')
titles = pd.read_csv(r'C:\Users\sdiou\Downloads\pycon-pandas-tutorial-master\pycon-pandas-tutorial-master\data\titles.csv')
titles.head()
# Out:
#                       title  year
# 0                 Doux amer  1989
# 1  Jiu wu tuo qiang nu jing  1995
# 2             Breaking Hart  2013
# 3                    Alamid  1967
# 4         The Learning Tree  1969

# %%
# cast = pd.read_csv('data/cast.csv')
cast = pd.read_csv(r'C:\Users\sdiou\Downloads\pycon-pandas-tutorial-master\pycon-pandas-tutorial-master\data\cast.csv', encoding = 'utf-8')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
titles.head()
# Out:
#                       title  year
# 0                 Doux amer  1989
# 1  Jiu wu tuo qiang nu jing  1995
# 2             Breaking Hart  2013
# 3                    Alamid  1967
# 4         The Learning Tree  1969

# %%
titles.tail()
# Out:
#                              title  year
# 226008               Yankesici kiz  1964
# 226009         Night in Montmartre  1931
# 226010         Kapitanskaya dochka  1928
# 226011  The Monkey King's Daughter  2018
# 226012             Mark Six Comedy  2004

# %% [markdown]
# ### Filtering
# let's you reduce donw to a criterion

# %%
h
# Out:
#                                                title  year
# 0                                          Doux amer  1989
# 1                           Jiu wu tuo qiang nu jing  1995
# 2                                      Breaking Hart  2013
# 3                                             Alamid  1967
# 4                                  The Learning Tree  1969
# 5                                      Just Tell Her  2017
# 6  The Incredible Adventure of Jojo (And His Anno...  2014
# 7                        La ragazza del vagone letto  1980

# %%
turn year into decade
h.year // 10 * 10
# Out:
# 0    1980
# 1    1990
# 2    2010
# 3    1960
# 4    1960
# 5    2010
# 6    2010
# 7    1980
# Name: year, dtype: int64

# %%
h.year > 1985
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# Name: year, dtype: bool

# %%
h[(h.year <= 1980) | (h.year>= 2000)]
# Out:
#                                                title  year
# 2                                      Breaking Hart  2013
# 3                                             Alamid  1967
# 4                                  The Learning Tree  1969
# 5                                      Just Tell Her  2017
# 6  The Incredible Adventure of Jojo (And His Anno...  2014
# 7                        La ragazza del vagone letto  1980

# %%
titles
# Out:
#                              title  year
# 0                        Doux amer  1989
# 1         Jiu wu tuo qiang nu jing  1995
# 2                    Breaking Hart  2013
# 3                           Alamid  1967
# 4                The Learning Tree  1969
# ...                            ...   ...
# 226008               Yankesici kiz  1964
# 226009         Night in Montmartre  1931
# 226010         Kapitanskaya dochka  1928
# 226011  The Monkey King's Daughter  2018
# 226012             Mark Six Comedy  2004
#
# [226013 rows x 2 columns]

# %%
t = titles
t[t.title == 'Macbeth'].sort_values('year').tail()
# Out:
#           title  year
# 64363   Macbeth  2013
# 93878   Macbeth  2014
# 86763   Macbeth  2015
# 174025  Macbeth  2017
# 78368   Macbeth  2018

# %%
h = cast.head()
h = h[h.n.notnull()]
# h[h.n.isnull()]
h
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
# How many movies are listed in the titles dataframe?
print("there are " + str(len(titles)) + " in the data base")
# Out:
# there are 226013 in the data base

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year', ascending=True).head(2)
# Out:
#                      title  year
# 37137           Miss Jerry  1894
# 113960  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the single-word title "Hamlet"?

# %%
len(titles[t.title == 'Hamlet'] )
# Out:
# 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[t.title == 'North by Northwest'] )
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[t.title == 'Hamlet'].sort_values('year').head(1)
# Out:
#          title  year
# 210546  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[t.title == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 22242   Treasure Island  1918
# 163882  Treasure Island  1920
# 191181  Treasure Island  1934
# 189545  Treasure Island  1950
# 5708    Treasure Island  1972
# 64797   Treasure Island  1973
# 153281  Treasure Island  1985
# 194516  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[t.year == 1950])
# Out:
# 1109

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[t.year == 1960])
# Out:
# 1496

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len (titles[ (titles.year >= 1950) & (titles.year <1960)] )
# Out:
# 12664

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles [t.title == 'Batman']
# Out:
#          title  year
# 84535   Batman  1989
# 187455  Batman  1943

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
len(cast[cast.title == 'Inception'])
# Out:
# 78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
c = cast
i = c[(c.title == 'Inception') & (c.n.isnull())]
len(i)
# h[h.n.isnull()]
# h
# Out:
# 27

# %%
# Out:
# 51

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
c = cast
i = c[(c.title == 'Inception') & (c.n.notnull())]
len(i)

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
c = cast
i = c[(c.title == 'North by Northwest') & (c.n.notnull())].sort_values('n')
i
# Out:
#                       title  year                  name     type  \
# 797150   North by Northwest  1959            Cary Grant    actor
# 3201980  North by Northwest  1959       Eva Marie Saint  actress
# 1333732  North by Northwest  1959           James Mason    actor
# 2878461  North by Northwest  1959   Jessie Royce Landis  actress
# 326415   North by Northwest  1959        Leo G. Carroll    actor
# 2780220  North by Northwest  1959  Josephine Hutchinson  actress
# 1551491  North by Northwest  1959           Philip Ober    actor
# 1167105  North by Northwest  1959         Martin Landau    actor
# 2239203  North by Northwest  1959         Adam Williams    actor
# 1657968  North by Northwest  1959          Edward Platt    actor
# 609229   North by Northwest  1959     Robert Ellenstein    actor
# 2100440  North by Northwest  1959          Les Tremayne    actor
# 425645   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
c = cast
s = c[(c.title == 'Sleuth') & (s.year == 1972)]
s = s.sort_values('n')
s
# Out:
#           title  year                name     type  \
# 1560814  Sleuth  1972    Laurence Olivier    actor
# 299291   Sleuth  1972       Michael Caine    actor
# 342151   Sleuth  1972      Alec Cawthorne    actor
# 1341313  Sleuth  1972  John (II) Matthews    actor
# 2490141  Sleuth  1972  Eve (III) Channing  actress
# 1325945  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1560814                 Andrew Wyke  1.0
# 299291                  Milo Tindle  2.0
# 342151            Inspector Doppler  3.0
# 1341313  Detective Sergeant Tarrant  4.0
# 2490141             Marguerite Wyke  5.0
# 1325945      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
c = cast
s = c[(c.title == 'Sleuth') & (c.year == 2007)]
s = s.sort_values('n')
s
# Out:
#           title  year                 name     type          character    n
# 299292   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1183659  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1652936  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 238747   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 342152   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2490140  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3069393  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
c = cast
c = c [(c.title == 'Hamlet') & (c.year == 1921) ]
len (c.character)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
c = cast
c = c [(c.title == 'Hamlet') & (c.year == 1996)]
len(c)
# Out:
# 54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
c = cast
c = c [ (c.character == 'Hamlet')]
len(c)
# Out:
# 93

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
c = cast
c = c [ (c.character == 'Ophelia')]
len(c)
# Out:
# 102

# %%
c = cast
c = c [ (c.character == 'Ophelia')] #.name.unique()
len (c.name.unique() )
# Out:
# 101

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
c = cast
c = c [ (c.character == 'The Dude')] #.name.unique()
len (c.name.unique() )
# c
# Out:
# 17

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
c = cast
c = c [ (c.character == 'The Stranger')] #.name.unique()
len (c.name.unique() )
# Out:
# 160

# %%
# solution

# How many people have played a role called "The Stranger"?

c = cast
len(c[c.character == 'The Stranger'].name.unique())
# Out:
# 160

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
c = cast
c = c [ (c.name == 'Sidney Poitier')] #.name.unique()
len (c.character.unique() )
# c
# Out:
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
c = cast
c = c [ (c.name == 'Judi Dench')] #.name.unique()
len (c.character.unique() )
# len (c.character )
# Out:
# 46

# %%
# How many roles has Judi Dench played?

c = cast
c = c[c.name == 'Judi Dench']
len(c)
# Out:
# 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
c = cast
c = c [ (c.name == 'Cary Grant')] #.name.unique()
# len (c.character.unique() )
c = c [c.year.notnull()]
# c[c.year] // 10 * 10
c = (c[c.n == 2])
c = c [ (c.year // 10 * 10 == 1940)].sort_values('year')
c
# Out:
#                    title  year        name   type    character    n
# 797147  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 797157    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?
